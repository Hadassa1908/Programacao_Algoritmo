# %%
#PerArea
alt = input("Entre com a altura: ")
alt = float(alt)
comp = input("Entre com o comprimento: ")
comp = float(comp)
per = (alt*2)+(comp*2)
area = comp*alt
print("Perímetro: ", per)
print("Área: ", area)
